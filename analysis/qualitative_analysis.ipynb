# %% [markdown]
# # RQ1 - Qualitative Analysis (examples and edge cases)

# %% [markdown]
# ### Mandatory import

# %%
from helper import show_qualitative_pair, show_qualitative_pair_by_id

# %% [markdown]
# # pre-LLM project

# %%
PROJECT_NAME = "0147_Azure-Samples_modern-data-warehouse-dataops_c2d86e5f4d44"

# %% [markdown]
# ## High cosine sim and CodeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.7, .9),
    codebleu_range=(0.7, 1.0),
    select_by="sim",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0147_Azure-Samples_modern-data-warehouse-dataops_c2d86e5f4d44
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.771896
# CodeBLEU:           0.782863
#
# Pair ID: 9e398215-305b-5070-919d-fdad9308820a::1ba92be3-5d69-5e2a-9b46-0c73447fcac9
#
# ...
# FUNCTION A
# ...
# Function:       launch
# Qualified name: launch
# Class:          None
# File:           main.py
# Path:           single_tech_samples/databricks/sample4_ci_cd/spark_python_jobs/main.py
# Package:        single_tech_samples.databricks.sample4_ci_cd.spark_python_jobs
# Lines:          23--33
# def launch(self):
#         df = self.spark.createDataFrame([('Fiji Apple', 'Red', 3.5),
#                            ('Banana', 'Yellow', 1.0),
#                            ('Green Grape', 'Green', 2.0),
#                            ('Red Grape', 'Red', 2.0),
#                            ('Peach', 'Yellow', 3.0),
# ...

# %% [markdown]
# # LLM Example

# %%
LLM_PROJECT_NAME = "0148_Azure-Samples_modern-data-warehouse-dataops_4bf9af83336f"

# %% [markdown]
# ## High cosine sim and low CodeBLEU

# %%
show_qualitative_pair(
    LLM_PROJECT_NAME,
    sim_range=(0.7, .9),
    codebleu_range=(0.0, .35),
    select_by="sim",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0148_Azure-Samples_modern-data-warehouse-dataops_4bf9af83336f
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.898333
# CodeBLEU:           0.324270
#
# Pair ID: 078d4dec-84ac-5463-ab36-f18e7f499367::46c6daa7-250b-5bd3-a167-9d1e54436b71
#
# ...
# FUNCTION A
# ...
# Function:       get_consumer_source_datasets
# Qualified name: get_consumer_source_datasets
# Class:          None
# File:           dest.py
# Path:           archive/single_tech_samples/datashare_automated_data_sharing/python/dest.py
# Package:        archive.single_tech_samples.datashare_automated_data_sharing.python
# Lines:          62--74
# def get_consumer_source_datasets(
#     client: DataShareManagementClient, subscription_name: str
# ):
#     # get source datasets
#     print("\
# ### Get Consumer Source Datasets ###")
#     result = client.consumer_source_data_sets.list_by_share_subscription(
# ...

# %% [markdown]
# # Agentic Example

# %%
AG_PROJECT_NAME = "0149_Azure-Samples_modern-data-warehouse-dataops_c6c097f74891"

# %% [markdown]
# ## High cosine sim and CodeBLEU

# %%
show_qualitative_pair(
    AG_PROJECT_NAME,
    sim_range=(0.7, .9),
    codebleu_range=(0.7, 1.0),
    select_by="sim",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0149_Azure-Samples_modern-data-warehouse-dataops_c6c097f74891
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.824346
# CodeBLEU:           0.788234
#
# Pair ID: feb7dcdc-9bc5-58a3-b24c-1b6c49e18b6d::6eae0a40-59d8-5a77-bbde-6230acbff8c9
#
# ...
# FUNCTION A
# ...
# Function:       get_workspace_id
# Qualified name: get_workspace_id
# Class:          None
# File:           utils.py
# Path:           fabric/fabric_dataops_sample/devops/scripts/utils.py
# Package:        fabric.fabric_dataops_sample.devops.scripts
# Lines:          20--37
# def get_workspace_id(headers: dict, workspace_name: str) -> Optional[str]:
#
#     url = f"{fabric_api_endpoint}/workspaces"
#
#     response = requests.get(url, headers=headers)
#
#     if response.status_code == 200:
#         workspaces = response.json().get("value", [])
#
#         for workspace in workspaces:
# ...
