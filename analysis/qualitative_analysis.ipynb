# %% [markdown]
# # RQ1 - Qualitative Analysis (examples and edge cases)

# %% [markdown]
# ### Mandatory import

# %%
from helper import show_qualitative_pair, show_qualitative_pair_by_id

# %% [markdown]
# # pre-LLM project

# %%
PROJECT_NAME = "0147_Azure-Samples_modern-data-warehouse-dataops_c2d86e5f4d44"

# %% [markdown]
# ## High cosine sim and CodeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.7, .9),
    codebleu_range=(0.7, 1.0),
    select_by="sim",
)
# Out:
# ================================================================================
# QUALITATIVE EXAMPLE
# ================================================================================
# Project:            0147_Azure-Samples_modern-data-warehouse-dataops_c2d86e5f4d44
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.771896
# CodeBLEU:           0.782863
#
# Pair ID: 9e398215-305b-5070-919d-fdad9308820a::1ba92be3-5d69-5e2a-9b46-0c73447fcac9
#
# ================================================================================
# FUNCTION A
# ================================================================================
# Function:       launch
# Qualified name: launch
# Class:          None
# File:           main.py
# Path:           single_tech_samples/databricks/sample4_ci_cd/spark_python_jobs/main.py
# Package:        single_tech_samples.databricks.sample4_ci_cd.spark_python_jobs
# Lines:          23--33
# def launch(self):
#         df = self.spark.createDataFrame([('Fiji Apple', 'Red', 3.5),
#                            ('Banana', 'Yellow', 1.0),
#                            ('Green Grape', 'Green', 2.0),
#                            ('Red Grape', 'Red', 2.0),
#                            ('Peach', 'Yellow', 3.0),
#                            ('Orange', 'Orange', 2.0),
#                            ('Green Apple', 'Green', 2.5)],
#                            ['Fruit', 'Color', 'Price'])
#         df = self.transform_data(df)
#         df.write.format("parquet").mode("overwrite").save(self.output)
# ================================================================================
# FUNCTION B
# ================================================================================
# Function:       setUp
# Qualified name: setUp
# Class:          None
# File:           module_a_test.py
# Path:           single_tech_samples/databricks/sample4_ci_cd/common/tests/module_a_test.py
# Package:        single_tech_samples.databricks.sample4_ci_cd.common.tests
# Lines:          8--19
# def setUp(self):
#
#         self.spark = SparkSession.builder.master("local[1]").getOrCreate()
#         df = self.spark.createDataFrame([('Fiji Apple', 'Red', 3.5),
#                            ('Banana', 'Yellow', 1.0),
#                            ('Green Grape', 'Green', 2.0),
#                            ('Red Grape', 'Red', 2.0),
#                            ('Peach', 'Yellow', 3.0),
#                            ('Orange', 'Orange', 2.0),
#                            ('Green Apple', 'Green', 2.5)],
#                            ['Fruit', 'Color', 'Price'])
#         self.df = add_mount(df, 20)

# %% [markdown]
# ## High cosine, low CodeBleu

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.8, 1.0),
    codebleu_range=(0.3, 0.40),
    select_by="sim",
)
# Out:
# ================================================================================
# QUALITATIVE EXAMPLE
# ================================================================================
# Project:            0147_Azure-Samples_modern-data-warehouse-dataops_c2d86e5f4d44
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.845419
# CodeBLEU:           0.367404
#
# Pair ID: 66b46893-7476-5d3d-9676-f34059920ccb::f8a7bb29-79e7-537d-8579-6e7784298164
#
# ================================================================================
# FUNCTION A
# ================================================================================
# Function:       _blob_exists
# Qualified name: _blob_exists
# Class:          None
# File:           blob_storage.py
# Path:           e2e_samples/parking_sensors_synapse/tests/integrationtests/tests/dataconnectors/blob_storage.py
# Package:        e2e_samples.parking_sensors_synapse.tests.integrationtests.tests.dataconnectors
# Lines:          66--69
# def _blob_exists(blob_service_client, container, file_path):
#     """Check if blob exists"""
#     blob_container_client = blob_service_client.get_container_client(container)
#     return next(blob_container_client.list_blobs(file_path), None) is not None
# ================================================================================
# FUNCTION B
# ================================================================================
# Function:       _container_exists
# Qualified name: _container_exists
# Class:          None
# File:           blob_storage.py
# Path:           e2e_samples/parking_sensors/tests/integrationtests/tests/dataconnectors/blob_storage.py
# Package:        e2e_samples.parking_sensors.tests.integrationtests.tests.dataconnectors
# Lines:          72--74
# def _container_exists(blob_service_client, container):
#     """Check if container exists"""
#     return next(blob_service_client.list_containers(container), None) is not None

# %% [markdown]
# ## Low cosine sim and  codeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.0, 0.40),
    codebleu_range=(0.0, 4.0),
    select_by="codebleu",
)
# Out:
# ================================================================================
# QUALITATIVE EXAMPLE
# ================================================================================
# Project:            0147_Azure-Samples_modern-data-warehouse-dataops_c2d86e5f4d44
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.304958
# CodeBLEU:           0.628151
#
# Pair ID: daaf2159-0c33-52ab-a564-05e2a788883c::dfab80f9-95db-5941-a665-f640dd46f1b1
#
# ================================================================================
# FUNCTION A
# ================================================================================
# Function:       after_Records_Exist_Returns_Positive_Number
# Qualified name: after_Records_Exist_Returns_Positive_Number
# Class:          None
# File:           main_notebook_sql_test.py
# Path:           single_tech_samples/databricks/sample4_ci_cd/notebook_jobs/tests/main_notebook_sql_test.py
# Package:        single_tech_samples.databricks.sample4_ci_cd.notebook_jobs.tests
# Lines:          28--29
# def after_Records_Exist_Returns_Positive_Number(self):
#        sqlContext.sql('DROP TABLE IF EXISTS POPULATION_COUNT;')
# ================================================================================
# FUNCTION B
# ================================================================================
# Function:       after_First_Year_Returns_One_Record
# Qualified name: after_First_Year_Returns_One_Record
# Class:          None
# File:           main_notebook_sql_test.py
# Path:           single_tech_samples/databricks/sample4_ci_cd/notebook_jobs/tests/main_notebook_sql_test.py
# Package:        single_tech_samples.databricks.sample4_ci_cd.notebook_jobs.tests
# Lines:          42--43
# def after_First_Year_Returns_One_Record(self):
#        sqlContext.sql('DROP TABLE IF EXISTS FIRST_YEAR_POPULATION;')

# %% [markdown]
# # LLM Example

# %%
AG_PROJECT_NAME = "0148_Azure-Samples_modern-data-warehouse-dataops_4bf9af83336f"

# %% [markdown]
# ## High cosine sim and CodeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.7, .9),
    codebleu_range=(0.7, 1.0),
    select_by="sim",
)
# Out:
# ================================================================================
# QUALITATIVE EXAMPLE
# ================================================================================
# Project:            0147_Azure-Samples_modern-data-warehouse-dataops_c2d86e5f4d44
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.771896
# CodeBLEU:           0.782863
#
# Pair ID: 9e398215-305b-5070-919d-fdad9308820a::1ba92be3-5d69-5e2a-9b46-0c73447fcac9
#
# ================================================================================
# FUNCTION A
# ================================================================================
# Function:       launch
# Qualified name: launch
# Class:          None
# File:           main.py
# Path:           single_tech_samples/databricks/sample4_ci_cd/spark_python_jobs/main.py
# Package:        single_tech_samples.databricks.sample4_ci_cd.spark_python_jobs
# Lines:          23--33
# def launch(self):
#         df = self.spark.createDataFrame([('Fiji Apple', 'Red', 3.5),
#                            ('Banana', 'Yellow', 1.0),
#                            ('Green Grape', 'Green', 2.0),
#                            ('Red Grape', 'Red', 2.0),
#                            ('Peach', 'Yellow', 3.0),
#                            ('Orange', 'Orange', 2.0),
#                            ('Green Apple', 'Green', 2.5)],
#                            ['Fruit', 'Color', 'Price'])
#         df = self.transform_data(df)
#         df.write.format("parquet").mode("overwrite").save(self.output)
# ================================================================================
# FUNCTION B
# ================================================================================
# Function:       setUp
# Qualified name: setUp
# Class:          None
# File:           module_a_test.py
# Path:           single_tech_samples/databricks/sample4_ci_cd/common/tests/module_a_test.py
# Package:        single_tech_samples.databricks.sample4_ci_cd.common.tests
# Lines:          8--19
# def setUp(self):
#
#         self.spark = SparkSession.builder.master("local[1]").getOrCreate()
#         df = self.spark.createDataFrame([('Fiji Apple', 'Red', 3.5),
#                            ('Banana', 'Yellow', 1.0),
#                            ('Green Grape', 'Green', 2.0),
#                            ('Red Grape', 'Red', 2.0),
#                            ('Peach', 'Yellow', 3.0),
#                            ('Orange', 'Orange', 2.0),
#                            ('Green Apple', 'Green', 2.5)],
#                            ['Fruit', 'Color', 'Price'])
#         self.df = add_mount(df, 20)

# %% [markdown]
# # Agentic Example

# %%
AG_PROJECT_NAME = "0053_mattermost_docs_97e4b499534f"

# %% [markdown]
# ## High cosine sim and CodeBLEU

# %%
show_qualitative_pair_by_id(
    AG_PROJECT_NAME,
    function_ids=(
        "9325c742-434f-5d6b-8d21-5351d8b822f3",
        "e724ec6b-e57b-5ec6-bb75-9e1993745208",
    ),
)
# Out:
# ================================================================================
# QUALITATIVE EXAMPLE
# ================================================================================
# Project:            0053_mattermost_docs_97e4b499534f
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.989052
# CodeBLEU:           0.710755
#
# Pair ID: e724ec6b-e57b-5ec6-bb75-9e1993745208::9325c742-434f-5d6b-8d21-5351d8b822f3
#
# ================================================================================
# FUNCTION A
# ================================================================================
# Function:       old_status_iterator
# Qualified name: old_status_iterator
# Class:          None
# File:           __init__.py
# Path:           extensions/reredirects/__init__.py
# Package:        extensions.reredirects
# Lines:          333--353
# def old_status_iterator(
#     mapping: Mapping[str, str], summary: str, color: str = "darkgreen"
# ) -> tuple[str, str]:
#     """
#     Displays the status of iterating through a Dict/Mapping of strings. Taken from the Sphinx sources.
#
#     :param mapping: The iterable to iterate through
#     :param summary: A description of the action or operation
#     :param color: The color of the status text; defaults to `darkgreen`
#     :return: A tuple containing the next key-value pair from the iterable
#     """
#     line_count = 0
#     for item in mapping.items():
#         if line_count == 0:
#             logger.info(bold(summary), nonl=True)
#             line_count = 1
#         logger.info(item[0], color=color, nonl=True)
#         logger.info(" ", nonl=True)
#         yield item
#     if line_count == 1:
#         logger.info("")
# ================================================================================
# FUNCTION B
# ================================================================================
# Function:       old_list_status_iterator
# Qualified name: old_list_status_iterator
# Class:          None
# File:           __init__.py
# Path:           extensions/reredirects/__init__.py
# Package:        extensions.reredirects
# Lines:          396--416
# def old_list_status_iterator(
#     mapping: list[str], summary: str, color: str = "darkgreen"
# ) -> str:
#     """
#     Displays the status of iterating through a List of strings. Adapted from the Sphinx sources.
#
#     :param mapping: The List to iterate through
#     :param summary: A description of the action or operation
#     :param color: The color of the status text; defaults to `darkgreen`
#     :return: A tuple containing the next value from the List
#     """
#     line_count = 0
#     for item in mapping:
#         if line_count == 0:
#             logger.info(bold(summary), nonl=True)
#             line_count = 1
#         logger.info(item, color=color, nonl=True)
#         logger.info(" ", nonl=True)
#         yield item
#     if line_count == 1:
#         logger.info("")

# %% [markdown]
# ## High cosine, low CodeBleu

# %%
AG_PROJECT_NAME = "0057_hacs_integration_d03ae863c2c3"
show_qualitative_pair(
    AG_PROJECT_NAME,
    sim_range=(0.85, 1),
    codebleu_range=(0.2, 0.35),
    select_by="sim",
)
# Out:
# ================================================================================
# QUALITATIVE EXAMPLE
# ================================================================================
# Project:            0057_hacs_integration_d03ae863c2c3
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.975487
# CodeBLEU:           0.234919
#
# Pair ID: c0267b3b-57ac-58cf-914a-3e4d97951a49::aeb00f2d-778c-51be-9b3f-d9698888d354
#
# ================================================================================
# FUNCTION A
# ================================================================================
# Function:       is_default
# Qualified name: is_default
# Class:          None
# File:           base.py
# Path:           custom_components/hacs/base.py
# Package:        custom_components.hacs
# Lines:          297--301
# def is_default(self, repository_id: str | None = None) -> bool:
#         """Check if a repository is default."""
#         if not repository_id:
#             return False
#         return repository_id in self._default_repositories
# ================================================================================
# FUNCTION B
# ================================================================================
# Function:       get_by_id
# Qualified name: get_by_id
# Class:          None
# File:           base.py
# Path:           custom_components/hacs/base.py
# Package:        custom_components.hacs
# Lines:          329--333
# def get_by_id(self, repository_id: str | None) -> HacsRepository | None:
#         """Get repository by id."""
#         if not repository_id:
#             return None
#         return self._repositories_by_id.get(str(repository_id))

# %% [markdown]
# ## Low cosine sim and  codeBLEU

# %%
show_qualitative_pair(
    AG_PROJECT_NAME,
    sim_range=(0, 0.3),
    codebleu_range=(0.0, .35),
    select_by="sim",
)
# Out:
# ================================================================================
# QUALITATIVE EXAMPLE
# ================================================================================
# Project:            0053_mattermost_docs_97e4b499534f
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.299932
# CodeBLEU:           0.003588
#
# Pair ID: 81761e87-5828-5cba-b919-87f9ab755889::71727d32-97d8-52a9-8576-94dc974292cc
#
# ================================================================================
# FUNCTION A
# ================================================================================
# Function:       find_duplicate_redirects
# Qualified name: find_duplicate_redirects
# Class:          None
# File:           conf.py
# Path:           source/conf.py
# Package:        source
# Lines:          11--46
# def find_duplicate_redirects(redirects):
#     # Track sources that map to the same target
#     target_to_sources = {}
#     # Track duplicate sources
#     duplicate_sources = {}
#
#     # Open warnings log file in build directory
#     with open("build/warnings.log", "w") as log:
#         for source, target in redirects.items():
#             # Check for duplicate sources
#             if source in duplicate_sources:
#                 warning = f"\
# Duplicate redirect found:\
# "
#                 warning += f"Source: {source}\
# "
#                 warning += f"Already maps to: {duplicate_sources[source]}\
# "
#                 warning += f"Also maps to: {target}\
# "
#                 log.write(warning)
#                 print(warning)
#             else:
#                 duplicate_sources[source] = target
#
#             # Track sources mapping to same target
#             if target in target_to_sources:
#                 target_to_sources[target].append(source)
#             else:
#                 target_to_sources[target] = [source]
#
#         # Log sources that map to the same target
#         for target, sources in target_to_sources.items():
#             if len(sources) > 1:
#                 warning = f"\
# Multiple sources map to same target:\
# "
#                 warning += f"Target: {target}\
# "
#                 warning += f"Sources: {sources}\
# "
#                 log.write(warning)
#                 print(warning)
#
#     return len(duplicate_sources) == len(redirects)
# ================================================================================
# FUNCTION B
# ================================================================================
# Function:       validate_refuri
# Qualified name: validate_refuri
# Class:          None
# File:           validate-refuris.py
# Path:           scripts/validate-refuris.py
# Package:        scripts
# Lines:          24--45
# def validate_refuri(node: nodes.reference, invalid_refs: List[str]):
#     if "refuri" in node.attributes:
#         refuri: str = node["refuri"]
#         # remove docs.mattermost.com prefix since that's the base URL
#         if refuri.startswith("https://docs.mattermost.com"):
#             refuri = refuri.removeprefix("https://docs.mattermost.com")
#         # if the reference is to the root of the site, it's considered valid
#         if refuri == "/":
#             return
#         # if this reference is an absolute reference to a page
#         if refuri.startswith("/"):
#             # remove the URI fragment if there is one
#             toks = refuri.split("#", 1)
#             uri_path = toks[0].removesuffix(".html")
#             # remove the URI query if there is one
#             toks = uri_path.split("?", 1)
#             uri_path = toks[0]
#             # construct the target doctree path and filename
#             target_doctree = "%s%s.doctree" % (BASE_DIR, uri_path)
#             if not path.exists(target_doctree):
#                 # the target doctree file does not exist
#                 invalid_refs.append(node["refuri"])
