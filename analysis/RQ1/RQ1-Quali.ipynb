# %% [markdown]
# # RQ1 - Clones (examples and edge cases)

# %% [markdown]
# ### Mandatory import

# %%
from helper import show_qualitative_pair

# %% [markdown]
# # Non-agentic project

# %%
PROJECT_NAME = "0052_mattermost_docs_d6b999846a57"

# %% [markdown]
# ## High cosine sim and CodeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.70, 1),
    codebleu_range=(0.5, 1.0),
    select_by="sim",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0052_mattermost_docs_d6b999846a57
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.883008
# CodeBLEU:           0.615748
#
# Pair ID: 47806a1d-4a94-5c60-9526-1b5c27f01605::f5f5befe-37e6-5205-92be-8c9c2f39ceca
#
# ...
# FUNCTION A
# ...
# Function:       old_status_iterator
# Qualified name: old_status_iterator
# Class:          None
# File:           __init__.py
# Path:           extensions/reredirects/__init__.py
# Package:        extensions.reredirects
# Lines:          87--105
# def old_status_iterator(mapping: Mapping[str, str], summary: str, color: str = "darkgreen") -> Tuple[str, str]:
#     """
#     Displays the status of iterating through a Dict/Mapping of strings. Taken from the Sphinx sources.
#
#     :param mapping: The iterable to iterate through
#     :param summary: A description of the action or operation
#     :param color: The color of the status text; defaults to `darkgreen`
# ...

# %% [markdown]
# ## High cosine, low CodeBleu

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.8, 1.0),
    codebleu_range=(0.0, 0.30),
    select_by="sim",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0052_mattermost_docs_d6b999846a57
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.938644
# CodeBLEU:           0.253469
#
# Pair ID: 9692cc16-7020-521d-8ba1-14affa6fc9eb::e570f591-bbc1-5e98-883f-5c68a0d3c246
#
# ...
# FUNCTION A
# ...
# Function:       env_merge_info
# Qualified name: env_merge_info
# Class:          None
# File:           __init__.py
# Path:           extensions/sitemap/__init__.py
# Package:        extensions.sitemap
# Lines:          115--141
# def env_merge_info(app: Sphinx, env: BuildEnvironment, docnames: List[str], other: BuildEnvironment):
#     """
#     Merge collected document names from parallel readers (workers) into the master Sphinx environment.
#     This function is called when the Sphinx `env-merge-info` event is fired.
#
#     :param app: The Sphinx Application instance
#     :param env: The master Sphinx BuildEnvironment
# ...

# %% [markdown]
# ## Low cosine sim and  codeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.0, 0.40),
    codebleu_range=(0.0, 4.0),
    select_by="codebleu",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0052_mattermost_docs_d6b999846a57
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.292496
# CodeBLEU:           0.250850
#
# Pair ID: 9692cc16-7020-521d-8ba1-14affa6fc9eb::4746cd88-6d07-5a9d-bb40-9a64bc85ca75
#
# ...
# FUNCTION A
# ...
# Function:       env_merge_info
# Qualified name: env_merge_info
# Class:          None
# File:           __init__.py
# Path:           extensions/sitemap/__init__.py
# Package:        extensions.sitemap
# Lines:          115--141
# def env_merge_info(app: Sphinx, env: BuildEnvironment, docnames: List[str], other: BuildEnvironment):
#     """
#     Merge collected document names from parallel readers (workers) into the master Sphinx environment.
#     This function is called when the Sphinx `env-merge-info` event is fired.
#
#     :param app: The Sphinx Application instance
#     :param env: The master Sphinx BuildEnvironment
# ...

# %% [markdown]
# # Agentic Example

# %%
PROJECT_NAME = "0053_mattermost_docs_97e4b499534f"

# %% [markdown]
# ## High cosine sim and CodeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.80, 0.9),
    codebleu_range=(0.80, 1.0),
    select_by="sim",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0053_mattermost_docs_97e4b499534f
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.844603
# CodeBLEU:           0.877792
#
# Pair ID: bb1a0ec5-0a6f-59c3-92ce-de5a08566c2a::2f68351c-f6f0-5fb6-b533-32420ee68a1b
#
# ...
# FUNCTION A
# ...
# Function:       starttag
# Qualified name: starttag
# Class:          None
# File:           dump-doctree.py
# Path:           scripts/dump-doctree.py
# Package:        scripts
# Lines:          114--126
# def starttag(node: nodes.Element):
#     parts = ["%s.%s" % (node.__class__.__module__, node.__class__.__name__)]
#     for attr, truncate_func in [
#         ("source", truncate_path),
#         ("line", str),
#         ("rawsource", truncate),
#     ]:
#         value = getattr(node, attr, None)
#         if value is not None:
#             parts.append("%s=%s" % (attr, quote(truncate_func(value))))
#     if translatable(node):
# ...

# %% [markdown]
# ## High cosine, low CodeBleu

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.85, 1.0),
    codebleu_range=(0.0, 0.20),
    select_by="sim",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0053_mattermost_docs_97e4b499534f
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.952097
# CodeBLEU:           0.103218
#
# Pair ID: cc020e27-578c-53ff-abe4-262322b7e4d0::3fd834bc-99f0-5b03-b2a1-5a66dadfa7de
#
# ...
# FUNCTION A
# ...
# Function:       is_leaf_node
# Qualified name: is_leaf_node
# Class:          None
# File:           dump-doctree.py
# Path:           scripts/dump-doctree.py
# Package:        scripts
# Lines:          60--84
# def is_leaf_node(node: nodes.Element) -> bool:
#     if translatable(node) and has_rawsource(node):
#         return True
#     if isinstance(node, IGNORE_NODES + PENDING_NODES):
#         return True
#     if isinstance(node, nodes.label) and isinstance(node.parent, nodes.footnote):
#         # footnote > label
#         return True
#     if isinstance(node, nodes.label) and isinstance(node.parent, nodes.citation):
#         # citation > label
# ...

# %% [markdown]
# ## Low cosine sim and  codeBLEU

# %%
show_qualitative_pair(
    PROJECT_NAME,
    sim_range=(0.8, 1),
    codebleu_range=(0.0, .35),
    select_by="codebleu",
)
# Out:
# ...
# QUALITATIVE EXAMPLE
# ...
# Project:            0053_mattermost_docs_97e4b499534f
# Model:              microsoft/codebert-base-ft
# Language:           python
# Cosine similarity:  0.888670
# CodeBLEU:           0.349998
#
# Pair ID: 4aad9544-8023-5dc2-b84a-c896658f238e::9325c742-434f-5d6b-8d21-5351d8b822f3
#
# ...
# FUNCTION A
# ...
# Function:       status_iterator
# Qualified name: status_iterator
# Class:          None
# File:           __init__.py
# Path:           extensions/reredirects/__init__.py
# Package:        extensions.reredirects
# Lines:          356--393
# def status_iterator(
#     mapping: Mapping[str, str],
#     summary: str,
#     color: str = "darkgreen",
#     length: int = 0,
#     verbosity: int = 0,
# ) -> tuple[str, str]:
#     """
#     Displays the status of iterating through a Dict/Mapping of strings. Taken from the Sphinx sources.
#     Status includes percent of records in the iterable that have been iterated through.
#
# ...
